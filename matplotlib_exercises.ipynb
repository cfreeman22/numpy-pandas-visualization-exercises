# %% [markdown]
# ### 1 -  Use matplotlib to plot the following equation: y=x2−x+2

# %% [markdown]
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
#import pyplot module as alias plt
import matplotlib.pyplot as plt  

#import other libraries 
import numpy as np
import math
from random import randint
import random
import pandas as pd

# %%
def y(x):
    return x**2 - x + 1

print(y(0))
# Out:
# 1

# %%
x = [n  for n in range(0,39)]
y = [(n**2 - n + 2) for n in x]

plt.plot(x,y)
plt.xlabel('$x$')
plt.ylabel('$y = x^2 - x +2 $')
plt.title('Equation plotting')
# Out:
# Text(0.5, 1.0, 'Equation plotting')

# %% [markdown]
# ### - 2 Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# * y=√x
# * y = x3
# * y = 2x
# * y = 1/(x+1)

# %%
#y=√x
x = range(39)
y = [(math.sqrt(i)) for i in x]

plt.plot(x,y)
plt.xlabel('$x$')
plt.ylabel('$y =√x $')
plt.title('Equation plotting for $y =√x $ ')
# Out:
# Text(0.5, 1.0, 'Equation plotting for $y =√x $ ')

# %%
#y = x3
x = range(39)
y = [(i**3) for i in x]

plt.plot(x,y)
plt.xlabel('$x$')
plt.ylabel('$y =x3 $')
plt.title('Equation plotting for $y =x3 $ ')
# Out:
# Text(0.5, 1.0, 'Equation plotting for $y =x3 $ ')

# %%
#y = 2^x
x = range(39)
y = [(2**i) for i in x]

plt.plot(x,y)
plt.xlabel('$x$')
plt.ylabel('$y =2^x $')
plt.title('Equation plotting for $y =2^x $ ')
# Out:
# Text(0.5, 1.0, 'Equation plotting for $y =2^x $ ')

# %%
#y = 1/(x+1)
x = range(39)
y = [1/(i+1) for i in x]

plt.plot(x,y)
plt.xlabel('$x$')
plt.ylabel('$y =1/(x+1) $')
plt.title('Equation plotting for $y =1/(x+1 $ ')
# Out:
# Text(0.5, 1.0, 'Equation plotting for $y =1/(x+1 $ ')

# %% [markdown]
# ### - 3 Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
# plot different mathematical functions vs x in a single figure
x = [x  for x in range(0,26)]
#pi = math.pi

y1 = [(math.sqrt(x)) for x in x]
y2 = [(x**3) for x in x]
y3 = [(2**x) for x in x]
y4 = [(1/(x+1)) * -1 for x in x]

plt.figure(figsize = (8,8))

plt.suptitle('Various Math Functions', fontsize = 16)

plt.subplot(2,2,1)
plt.plot(x,y1, color = 'r', marker = '*')
plt.title('$y =√x $')
#plt.xticks([-2 * pi, -1 * pi, 0, pi, 2*pi], ['$2\pi$', '$\pi$', '0', '$\pi$', '$2\pi$'])

plt.subplot(2,2,2)
plt.plot(x, y2, color= 'b', marker = 's')
plt.title('$y =x3 $')



plt.subplot(2,2,3)
plt.plot(x, y3, color = 'g', marker = 'v')
plt.title('$y =2^x $')




plt.subplot(2,2,4)
plt.plot(x, y4, color = 'm', marker = 'o')
plt.title('$y =1/(x+1)$ ')
plt.axhline(0, color = 'm', lw = 0.5)
plt.fill_between(x, y4, color = 'm')

plt.tight_layout()

# %% [markdown]
# ### 4 - Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
x = [x  for x in range(4)]
 

y1 = [(math.sqrt(i)) for i in x]
y2 = [(i**3) for i in x]
y3 = [(2**i) for i in x]
y4 = [(1/(i+1)) * -1 for i in x]

plt.plot(x,y1, label='y = sqrt(x)')
plt.plot(x, y2,label='y = x**3' )
plt.plot(x,y3, label='y = 2**x')
plt.plot(x, y4, label='y = 1/(x +1)') 
plt.title('Various Math Functions')
plt.legend()
