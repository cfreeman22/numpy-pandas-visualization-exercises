# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ##### Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
def get_db_url(db_name):
    from env import username, host, password
    return f'mysql+pymysql://{username}:{password}@{host}/{db_name}'

# %% [markdown]
# ##### Use your function to obtain a connection to the employees database.

# %%
url = get_db_url("employees")

# %%
sql= '''
    SELECT * from employees 
'''

# %%
df = pd.read_sql(sql, url)
df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %% [markdown]
# ###### Read the employees and titles tables into two separate DataFrames.

# %%
sql2= '''
    SELECT * from titles 
'''

# %%
df = pd.read_sql(sql, url)
df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
df2 = pd.read_sql(sql2, url)
df2
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# ##### Display the summary statistics for each DataFrame.

# %%
df.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
df.shape
# Out:
# (300024, 6)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
df2.shape
# Out:
# (443308, 4)

# %%
df.columns
# Out:
# Index(['emp_no', 'birth_date', 'first_name', 'last_name', 'gender',
#        'hire_date'],
#       dtype='object')

# %% [markdown]
# ##### Exercise 2

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
#users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)

# %%
pd.merge(users,roles,on='id',how='right')
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter

# %%
pd.merge(users,roles,on='id',how='outer')
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter
# 4   5   jane      NaN        NaN
# 5   6   mike      NaN        NaN

# %%
roles.drop(roles.columns[[0]], axis=1, inplace=True)

# %%
#pd.merge(users,roles,on='id',how='right')

# %%
#pydataset('mpg', show_doc =True)

# %%
from pydataset import data

# %%
mpg = data('mpg', show_doc =True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg = data('mpg')

# %%
mpg.tail(10)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 225   volkswagen  new beetle    2.0  1999    4    auto(l4)   f   19   26  r
# 226   volkswagen  new beetle    2.5  2008    5  manual(m5)   f   20   28  r
# 227   volkswagen  new beetle    2.5  2008    5    auto(s6)   f   20   29  r
# 228   volkswagen      passat    1.8  1999    4  manual(m5)   f   21   29  p
# 229   volkswagen      passat    1.8  1999    4    auto(l5)   f   18   29  p
# 230   volkswagen      passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen      passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen      passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen      passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen      passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#           class
# 225  subcompact
# 226  subcompact
# 227  subcompact
# 228     midsize
# 229     midsize
# 230     midsize
# ...

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg.rename(columns={'displ': 'display', 'cty': 'city', 'hwy':'highway'}, inplace=True)
mpg
# Out:
#     manufacturer   model  display  year  cyl       trans drv  city  highway  \
# 1           audi      a4      1.8  1999    4    auto(l5)   f    18       29
# 2           audi      a4      1.8  1999    4  manual(m5)   f    21       29
# 3           audi      a4      2.0  2008    4  manual(m6)   f    20       31
# 4           audi      a4      2.0  2008    4    auto(av)   f    21       30
# 5           audi      a4      2.8  1999    6    auto(l5)   f    16       26
# ..           ...     ...      ...   ...  ...         ...  ..   ...      ...
# 230   volkswagen  passat      2.0  2008    4    auto(s6)   f    19       28
# 231   volkswagen  passat      2.0  2008    4  manual(m6)   f    21       29
# 232   volkswagen  passat      2.8  1999    6    auto(l5)   f    16       26
# 233   volkswagen  passat      2.8  1999    6  manual(m5)   f    18       26
# 234   volkswagen  passat      3.6  2008    6    auto(s6)   f    17       26
#
#     fl    class
# 1    p  compact
# 2    p  compact
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   display       234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   city          234 non-null    int64
#  8   highway       234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe()
# Out:
#           display         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# ##### How many diffrent manufacturers are there?

# %%
mpg.manufacturer.value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# hyundai       14
# subaru        14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# mercury        4
# land rover     4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
len(mpg.manufacturer.unique())
# Out:
# 15

# %%
mpg.model.value_counts()
# Out:
# caravan 2wd               11
# ram 1500 pickup 4wd       10
# dakota pickup 4wd          9
# jetta                      9
# mustang                    9
# civic                      9
# grand cherokee 4wd         8
# impreza awd                8
# a4 quattro                 8
# a4                         7
# toyota tacoma 4wd          7
# sonata                     7
# durango 4wd                7
# f150 pickup 4wd            7
# passat                     7
# tiburon                    7
# camry                      7
# camry solara               7
# new beetle                 6
# explorer 4wd               6
# altima                     6
# 4runner 4wd                6
# forester awd               6
# c1500 suburban 2wd         5
# grand prix                 5
# corvette                   5
# corolla                    5
# gti                        5
# malibu                     5
# k1500 tahoe 4wd            4
# pathfinder 4wd             4
# mountaineer 4wd            4
# ...

# %%
len(mpg.model.unique())
# Out:
# 38

# %% [markdown]
# ##### 12 - Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg['highway'] - mpg['city']

# %%
mpg
# Out:
#     manufacturer   model  display  year  cyl       trans drv  city  highway  \
# 1           audi      a4      1.8  1999    4    auto(l5)   f    18       29
# 2           audi      a4      1.8  1999    4  manual(m5)   f    21       29
# 3           audi      a4      2.0  2008    4  manual(m6)   f    20       31
# 4           audi      a4      2.0  2008    4    auto(av)   f    21       30
# 5           audi      a4      2.8  1999    6    auto(l5)   f    16       26
# ..           ...     ...      ...   ...  ...         ...  ..   ...      ...
# 230   volkswagen  passat      2.0  2008    4    auto(s6)   f    19       28
# 231   volkswagen  passat      2.0  2008    4  manual(m6)   f    21       29
# 232   volkswagen  passat      2.8  1999    6    auto(l5)   f    16       26
# 233   volkswagen  passat      2.8  1999    6  manual(m5)   f    18       26
# 234   volkswagen  passat      3.6  2008    6    auto(s6)   f    17       26
#
#     fl    class  mileage_difference
# ...

# %% [markdown]
# ##### 13 Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.highway + mpg.city)/2

# %%
mpg
# Out:
#     manufacturer   model  display  year  cyl       trans drv  city  highway  \
# 1           audi      a4      1.8  1999    4    auto(l5)   f    18       29
# 2           audi      a4      1.8  1999    4  manual(m5)   f    21       29
# 3           audi      a4      2.0  2008    4  manual(m6)   f    20       31
# 4           audi      a4      2.0  2008    4    auto(av)   f    21       30
# 5           audi      a4      2.8  1999    6    auto(l5)   f    16       26
# ..           ...     ...      ...   ...  ...         ...  ..   ...      ...
# 230   volkswagen  passat      2.0  2008    4    auto(s6)   f    19       28
# 231   volkswagen  passat      2.0  2008    4  manual(m6)   f    21       29
# 232   volkswagen  passat      2.8  1999    6    auto(l5)   f    16       26
# 233   volkswagen  passat      2.8  1999    6  manual(m5)   f    18       26
# 234   volkswagen  passat      3.6  2008    6    auto(s6)   f    17       26
#
#     fl    class  mileage_difference  average_mileage
# ...

# %% [markdown]
# ##### - 14  Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans.str.startswith('a')

# %%
mpg
# Out:
#     manufacturer   model  display  year  cyl       trans drv  city  highway  \
# 1           audi      a4      1.8  1999    4    auto(l5)   f    18       29
# 2           audi      a4      1.8  1999    4  manual(m5)   f    21       29
# 3           audi      a4      2.0  2008    4  manual(m6)   f    20       31
# 4           audi      a4      2.0  2008    4    auto(av)   f    21       30
# 5           audi      a4      2.8  1999    6    auto(l5)   f    16       26
# ..           ...     ...      ...   ...  ...         ...  ..   ...      ...
# 230   volkswagen  passat      2.0  2008    4    auto(s6)   f    19       28
# 231   volkswagen  passat      2.0  2008    4  manual(m6)   f    21       29
# 232   volkswagen  passat      2.8  1999    6    auto(l5)   f    16       26
# 233   volkswagen  passat      2.8  1999    6  manual(m5)   f    18       26
# 234   volkswagen  passat      3.6  2008    6    auto(s6)   f    17       26
#
# ...

# %% [markdown]
# ##### 15 Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
#mpg.average_mileage.()
# Out:
# 10.5

# %%
mpg.groupby('manufacturer').average_mileage.agg('mean').sort_values().tail(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %%
#mpg.average_mileage.agg(['max'])
# Out:
# max    39.5
# Name: average_mileage, dtype: float64

# %%
#mpg[mpg.average_mileage == mpg.average_mileage.max()]
# Out:
#     manufacturer       model  display  year  cyl       trans drv  city  \
# 222   volkswagen  new beetle      1.9  1999    4  manual(m5)   f    35
#
#      highway fl       class  mileage_difference  average_mileage  is_automatic
# 222       44  d  subcompact                   9             39.5         False

# %% [markdown]
# ##### 16 Do automatic or manual cars have better miles per gallon?

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# ##### 3 - 1 Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url_chiplt = get_db_url("chipotle")

#url_chiplt

# %%
querry_chiplt = '''
    SELECT * from orders
'''

# %%
chipotle = pd.read_sql(querry_chiplt, url_chiplt)

# %%
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %% [markdown]
# ##### 3 - 2 What is the total price for each order?

# %%
chipotle['item_price'] = chipotle['item_price'].str.strip('$')

# %%
chipotle['item_price'] = chipotle['item_price'].astype(float)

# %%
#chipotle['item_price'] = chipotle.astype(float)

# %%
chipotle.groupby('order_id').item_price.agg('sum')
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
chipotle['total_price']= chipotle['quantity'] * chipotle['item_price']

# %% [markdown]
# ##### 3 -3 What are the most popular 3 items?

# %%
chipotle.nlargest(3, 'quantity')
# Out:
#         id  order_id  quantity                     item_name  \
# 3598  3599      1443        15  Chips and Fresh Tomato Salsa
# 4152  4153      1660        10                 Bottled Water
# 3887  3888      1559         8                 Side of Chips
#
#      choice_description  item_price  total_price
# 3598                nan       44.25       663.75
# 4152                nan       15.00       150.00
# 3887                nan       13.52       108.16

# %%
items = chipotle.groupby('item_name').quantity.sum()
items
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
items.nlargest(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# ##### 3 - 4 Which item has produced the most revenue?

# %%
chipotle.groupby('item_name').item_price.agg('sum').sort_values(ascending= False).head(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %%
#item withnthe least revenue
chipotle.groupby('item_name').item_price.agg('sum').sort_values(ascending= False).tail(1)
# Out:
# item_name
# Chips and Mild Fresh Tomato Salsa    3.0
# Name: item_price, dtype: float64

# %%
items_rev = chipotle.groupby('item_name').quantity.sum()
items_rev
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...
